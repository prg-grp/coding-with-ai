# %% [markdown]
# # Tutorial: AI for Software Projects
#
# Welcome! This tutorial will guide you through some of the most common uses of AI in software project development. We encourage you to use the examples only as suggestions and to experiment with AI, stretching its capabilities with larger and more complex examples. Happy hacking!

# %% [markdown]
# ## Content
#
# [APIs with AI tools](./AI-sw-prj_api.ipynb)
#
# [Working with GUIs and AI](./AI-sw-prj_guis.ipynb)
#
# [Modularization using AI tools](./AI-sw-prj_modularization.ipynb)
#
# [Testing with AI](./AI-sw-prj_testing.ipynb)
